# %% [markdown]
# # Pandas

# %%
from pandas import DataFrame, Series
import pandas as pd
import numpy as np

# %%
df_weather = pd.read_csv('./Weather.csv',sep=',')

# %%
df_weather.head()
# Out:
#     code province        date  avg_temp  min_temp  max_temp  precipitation  \
# 0  10000    Seoul  2016-01-01       1.2      -3.3       4.0            0.0
# 1  11000    Busan  2016-01-01       5.3       1.1      10.9            0.0
# 2  12000    Daegu  2016-01-01       1.7      -4.0       8.0            0.0
# 3  13000  Gwangju  2016-01-01       3.2      -1.5       8.1            0.0
# 4  14000  Incheon  2016-01-01       3.1      -0.4       5.7            0.0
#
#    max_wind_speed  most_wind_direction  avg_relative_humidity
# 0             3.5                 90.0                   73.0
# 1             7.4                340.0                   52.1
# 2             3.7                270.0                   70.5
# 3             2.7                230.0                   73.1
# 4             5.3                180.0                   83.9

# %%
df_weather.values
# Out:
# array([[10000, 'Seoul', '2016-01-01', ..., 3.5, 90.0, 73.0],
#        [11000, 'Busan', '2016-01-01', ..., 7.4, 340.0, 52.1],
#        [12000, 'Daegu', '2016-01-01', ..., 3.7, 270.0, 70.5],
#        ...,
#        [60000, 'Gyeongsangbuk-do', '2020-04-29', ..., 7.3, 180.0, 42.6],
#        [61000, 'Gyeongsangnam-do', '2020-04-29', ..., 4.2, 50.0, 47.0],
#        [70000, 'Jeju-do', '2020-04-29', ..., 4.5, 20.0, 39.9]],
#       dtype=object)

# %%
type(df_weather.values)
# Out:
# numpy.ndarray

# %% [markdown]
# .

# %% [markdown]
# # column 이름으로 값을 가져오기

# %%
DataFrame(df_weather, columns = ['province','date', 'avg_temp'])
# Out:
#                province        date  avg_temp
# 0                 Seoul  2016-01-01       1.2
# 1                 Busan  2016-01-01       5.3
# 2                 Daegu  2016-01-01       1.7
# 3               Gwangju  2016-01-01       3.2
# 4               Incheon  2016-01-01       3.1
# ...                 ...         ...       ...
# 25290      Jeollabuk-do  2020-04-29      15.1
# 25291      Jeollanam-do  2020-04-29      15.6
# 25292  Gyeongsangbuk-do  2020-04-29      16.7
# 25293  Gyeongsangnam-do  2020-04-29      15.2
# 25294           Jeju-do  2020-04-29      15.9
#
# [25295 rows x 3 columns]

# %% [markdown]
# .

# %% [markdown]
# # loc, iloc

# %% [markdown]
# loc : index location
# iloc : index position

# %%
df_weather.loc[1:3]
# Out:
#     code province        date  avg_temp  min_temp  max_temp  precipitation  \
# 1  11000    Busan  2016-01-01       5.3       1.1      10.9            0.0
# 2  12000    Daegu  2016-01-01       1.7      -4.0       8.0            0.0
# 3  13000  Gwangju  2016-01-01       3.2      -1.5       8.1            0.0
#
#    max_wind_speed  most_wind_direction  avg_relative_humidity
# 1             7.4                340.0                   52.1
# 2             3.7                270.0                   70.5
# 3             2.7                230.0                   73.1

# %%
df_weather.iloc[1:3]
# Out:
#     code province        date  avg_temp  min_temp  max_temp  precipitation  \
# 1  11000    Busan  2016-01-01       5.3       1.1      10.9            0.0
# 2  12000    Daegu  2016-01-01       1.7      -4.0       8.0            0.0
#
#    max_wind_speed  most_wind_direction  avg_relative_humidity
# 1             7.4                340.0                   52.1
# 2             3.7                270.0                   70.5

# %%
s = pd.Series(np.nan, index = [49,50,51,52,53,1,2,3,4,5])

# %%
s.loc[:3]
# Out:
# 49   NaN
# 50   NaN
# 51   NaN
# 52   NaN
# 53   NaN
# 1    NaN
# 2    NaN
# 3    NaN
# dtype: float64

# %%
s.iloc[:3]
# Out:
# 49   NaN
# 50   NaN
# 51   NaN
# dtype: float64

# %% [markdown]
# .

# %% [markdown]
# # 조건으로 뽑아서 새로운 컬럼 생성

# %%
df_weather["high"] = df_weather["avg_temp"] > 4

# %%
df_weather.head(10)
# Out:
#     code           province        date  avg_temp  min_temp  max_temp  \
# 0  10000              Seoul  2016-01-01       1.2      -3.3       4.0
# 1  11000              Busan  2016-01-01       5.3       1.1      10.9
# 2  12000              Daegu  2016-01-01       1.7      -4.0       8.0
# 3  13000            Gwangju  2016-01-01       3.2      -1.5       8.1
# 4  14000            Incheon  2016-01-01       3.1      -0.4       5.7
# 5  15000            Daejeon  2016-01-01       1.6      -4.2       7.7
# 6  16000              Ulsan  2016-01-01       4.0      -1.6      12.0
# 7  20000        Gyeonggi-do  2016-01-01       1.6      -4.2       5.7
# 8  30000         Gangwon-do  2016-01-01       5.1       2.1       8.9
# 9  40000  Chungcheongbuk-do  2016-01-01      -1.0      -5.9       4.1
#
#    precipitation  max_wind_speed  most_wind_direction  avg_relative_humidity  \
# 0            0.0             3.5                 90.0                   73.0
# ...

# %% [markdown]
# # Series  Selection

# %%
direction_series = df_weather["most_wind_direction"]
direction_series[:3]
# Out:
# 0     90.0
# 1    340.0
# 2    270.0
# Name: most_wind_direction, dtype: float64

# %%
direction_series[direction_series < 200][:10]
# Out:
# 0      90.0
# 4     180.0
# 7     180.0
# 9     110.0
# 10    180.0
# 11    140.0
# 14     20.0
# 15    180.0
# 20    180.0
# 21    110.0
# Name: most_wind_direction, dtype: float64

# %% [markdown]
# .

# %% [markdown]
# # transpose

# %%
df_weather.T
# Out:
#                             0           1           2           3      \
# code                        10000       11000       12000       13000
# province                    Seoul       Busan       Daegu     Gwangju
# date                   2016-01-01  2016-01-01  2016-01-01  2016-01-01
# avg_temp                      1.2         5.3         1.7         3.2
# min_temp                     -3.3         1.1          -4        -1.5
# max_temp                        4        10.9           8         8.1
# precipitation                   0           0           0           0
# max_wind_speed                3.5         7.4         3.7         2.7
# most_wind_direction            90         340         270         230
# avg_relative_humidity          73        52.1        70.5        73.1
# high                        False        True       False       False
#
#                             4           5           6            7      \
# ...

# %% [markdown]
# .

# %% [markdown]
# # column 삭제

# %%
del df_weather["high"]

# %%
df_weather
# Out:
#         code          province        date  avg_temp  min_temp  max_temp  \
# 0      10000             Seoul  2016-01-01       1.2      -3.3       4.0
# 1      11000             Busan  2016-01-01       5.3       1.1      10.9
# 2      12000             Daegu  2016-01-01       1.7      -4.0       8.0
# 3      13000           Gwangju  2016-01-01       3.2      -1.5       8.1
# 4      14000           Incheon  2016-01-01       3.1      -0.4       5.7
# ...      ...               ...         ...       ...       ...       ...
# 25290  50000      Jeollabuk-do  2020-04-29      15.1       7.8      23.0
# 25291  51000      Jeollanam-do  2020-04-29      15.6      11.3      20.2
# 25292  60000  Gyeongsangbuk-do  2020-04-29      16.7      11.0      25.1
# 25293  61000  Gyeongsangnam-do  2020-04-29      15.2       7.6      24.5
# 25294  70000           Jeju-do  2020-04-29      15.9      13.0      20.0
#
#        precipitation  max_wind_speed  most_wind_direction  \
# ...

# %% [markdown]
# .

# %% [markdown]
# # Selection with column names

# %%
df_weather["min_temp"].head(3)
# Out:
# 0   -3.3
# 1    1.1
# 2   -4.0
# Name: min_temp, dtype: float64

# %%
df_weather[["code", "province","date","min_temp"]].head(3)
# Out:
#     code province        date  min_temp
# 0  10000    Seoul  2016-01-01      -3.3
# 1  11000    Busan  2016-01-01       1.1
# 2  12000    Daegu  2016-01-01      -4.0

# %% [markdown]
# .

# %% [markdown]
# # 특정 column을 인덱스로

# %%
df_weather.index = df_weather["code"]

# %%
del df_weather["code"]

# %%
df_weather.head()
# Out:
#       province        date  avg_temp  min_temp  max_temp  precipitation  \
# code
# 10000    Seoul  2016-01-01       1.2      -3.3       4.0            0.0
# 11000    Busan  2016-01-01       5.3       1.1      10.9            0.0
# 12000    Daegu  2016-01-01       1.7      -4.0       8.0            0.0
# 13000  Gwangju  2016-01-01       3.2      -1.5       8.1            0.0
# 14000  Incheon  2016-01-01       3.1      -0.4       5.7            0.0
#
#        max_wind_speed  most_wind_direction  avg_relative_humidity
# code
# 10000             3.5                 90.0                   73.0
# 11000             7.4                340.0                   52.1
# 12000             3.7                270.0                   70.5
# 13000             2.7                230.0                   73.1
# 14000             5.3                180.0                   83.9

# %%
df_weather.values
# Out:
# array([['Seoul', '2016-01-01', 1.2, ..., 3.5, 90.0, 73.0],
#        ['Busan', '2016-01-01', 5.3, ..., 7.4, 340.0, 52.1],
#        ['Daegu', '2016-01-01', 1.7, ..., 3.7, 270.0, 70.5],
#        ...,
#        ['Gyeongsangbuk-do', '2020-04-29', 16.7, ..., 7.3, 180.0, 42.6],
#        ['Gyeongsangnam-do', '2020-04-29', 15.2, ..., 4.2, 50.0, 47.0],
#        ['Jeju-do', '2020-04-29', 15.9, ..., 4.5, 20.0, 39.9]],
#       dtype=object)

# %% [markdown]
# .

# %% [markdown]
# # Basic, loc, iloc

# %%
df_weather[["province","avg_temp"]][:2]
# Out:
#       province  avg_temp
# code
# 10000    Seoul       1.2
# 11000    Busan       5.3

# %%
df_weather.iloc[:2,:2]
# Out:
#       province        date
# code
# 10000    Seoul  2016-01-01
# 11000    Busan  2016-01-01
